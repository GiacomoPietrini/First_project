# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\giaco\\File Analisi Dati'

# %%
df = pd.read_csv("cleaned_global_water_consumption.CSV.csv")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Boolean1.ipynb',
#  'cleaned_global_water_consumption.CSV.csv',
#  'Final assignment.ipynb',
#  'GA Paid Search Traffic.csv',
#  'iris.csv',
#  'Progetto 1 prova.ipynb',
#  'Software Professionals Salary.csv',
#  'Untitled.ipynb']

# %%
df
# Out:
#        Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0    Argentina  2000                                      481.490000
# 1    Argentina  2001                                      455.063000
# 2    Argentina  2002                                      482.749231
# 3    Argentina  2003                                      452.660000
# 4    Argentina  2004                                      634.566000
# ..         ...   ...                                             ...
# 495        USA  2020                                      418.097000
# 496        USA  2021                                      572.094000
# 497        USA  2022                                      440.978000
# 498        USA  2023                                      566.865000
# 499        USA  2024                                      249.485000
#
#      Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Country                                         500 non-null    object
#  1   Year                                            500 non-null    int64
#  2   Total Water Consumption (Billion Cubic Meters)  500 non-null    float64
#  3   Per Capita Water Use (Liters per Day)           500 non-null    float64
#  4   Agricultural Water Use (%)                      500 non-null    float64
#  5   Industrial Water Use (%)                        500 non-null    float64
#  6   Household Water Use (%)                         500 non-null    float64
#  7   Rainfall Impact (Annual Precipitation in mm)    500 non-null    float64
#  8   Groundwater Depletion Rate (%)                  500 non-null    float64
# ...

# %%
df
# Out:
#        Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 0    Argentina  2000                                      481.490000
# 1    Argentina  2001                                      455.063000
# 2    Argentina  2002                                      482.749231
# 3    Argentina  2003                                      452.660000
# 4    Argentina  2004                                      634.566000
# ..         ...   ...                                             ...
# 495        USA  2020                                      418.097000
# 496        USA  2021                                      572.094000
# 497        USA  2022                                      440.978000
# 498        USA  2023                                      566.865000
# 499        USA  2024                                      249.485000
#
#      Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# ...

# %%
df['Year'] = pd.to_datetime(df['Year'], format='%Y')

# %%
df['Year'] = df['Year'].dt.year

# %%
df.isnull().sum()
# Out:
# Country                                           0
# Year                                              0
# Total Water Consumption (Billion Cubic Meters)    0
# Per Capita Water Use (Liters per Day)             0
# Agricultural Water Use (%)                        0
# Industrial Water Use (%)                          0
# Household Water Use (%)                           0
# Rainfall Impact (Annual Precipitation in mm)      0
# Groundwater Depletion Rate (%)                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df['Country'].unique()
# Out:
# array(['Argentina', 'Australia', 'Brazil', 'Canada', 'China', 'France',
#        'Germany', 'India', 'Indonesia', 'Italy', 'Japan', 'Mexico',
#        'Russia', 'Saudi Arabia', 'South Africa', 'South Korea', 'Spain',
#        'Turkey', 'UK', 'USA'], dtype=object)

# %%
paesi = ['Italy', 'India', 'South Korea']

df_filtrato = df[df['Country'].isin(paesi)]

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_filtrato, x='Year', y='Total Water Consumption (Billion Cubic Meters)', hue='Country', marker='o')

plt.title('Trend del consumo d’acqua nel tempo')
plt.xlabel('Anno')
plt.ylabel('Consumo totale di acqua')
plt.legend(title='Paese')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_consumo_acqua = df[['Country','Agricultural Water Use (%)','Industrial Water Use (%)','Household Water Use (%)']]
df_consumo_acqua
# Out:
#        Country  Agricultural Water Use (%)  Industrial Water Use (%)  \
# 0    Argentina                   48.550000                 20.844286
# 1    Argentina                   48.465000                 26.943000
# 2    Argentina                   50.375385                 29.042308
# 3    Argentina                   49.086667                 30.476000
# 4    Argentina                   38.670000                 36.670000
# ..         ...                         ...                       ...
# 495        USA                   47.448000                 25.266000
# 496        USA                   46.195000                 32.223000
# 497        USA                   54.810000                 30.918000
# 498        USA                   62.945000                 25.207500
# 499        USA                   51.386000                 24.769000
#
#      Household Water Use (%)
# 0                  30.100000
# 1                  22.550000
# 2                  23.349231
# ...

# %%
statistiche = df_consumo_acqua.groupby('Country').agg({
    'Agricultural Water Use (%)': ['mean','median','std'],
    'Industrial Water Use (%)': ['mean','median','std'],
    'Household Water Use (%)': ['mean','median','std']
})

statistiche
# Out:
#              Agricultural Water Use (%)                       \
#                                    mean     median       std
# Country
# Argentina                     51.437969  50.375385  6.488363
# Australia                     52.801331  53.561250  6.050442
# Brazil                        49.755676  50.249231  5.923861
# Canada                        50.328007  50.000000  4.228369
# China                         51.705375  50.887500  5.302112
# France                        48.696575  48.557692  5.004571
# Germany                       47.398331  46.782727  6.118173
# India                         49.792830  49.091538  6.992765
# Indonesia                     49.504249  50.790000  5.539633
# Italy                         49.649514  50.850000  4.453324
# Japan                         49.519145  50.405000  6.960338
# Mexico                        49.668012  49.267778  5.411112
# Russia                        50.531580  51.607500  3.806495
# ...

# %%
consumo_per_paese = df.groupby('Country')['Total Water Consumption (Billion Cubic Meters)'].sum()
consumo_per_paese
# Out:
# Country
# Argentina       13284.860759
# Australia       12505.778389
# Brazil          13263.287436
# Canada          12352.694690
# China           13133.596733
# France          12596.115707
# Germany         12668.588927
# India           12581.662785
# Indonesia       12151.267472
# Italy           12449.631513
# Japan           12585.683217
# Mexico          12058.054255
# Russia          12385.526576
# Saudi Arabia    12966.078679
# South Africa    12544.930893
# South Korea     12184.867481
# Spain           11796.579075
# Turkey          11882.584874
# UK              12161.474784
# USA             13058.950844
# Name: Total Water Consumption (Billion Cubic Meters), dtype: float64

# %%
consumo_ordinato = consumo_per_paese.sort_values(ascending= False)
consumo_ordinato
# Out:
# Country
# Argentina       13284.860759
# Brazil          13263.287436
# China           13133.596733
# USA             13058.950844
# Saudi Arabia    12966.078679
# Germany         12668.588927
# France          12596.115707
# Japan           12585.683217
# India           12581.662785
# South Africa    12544.930893
# Australia       12505.778389
# Italy           12449.631513
# Russia          12385.526576
# Canada          12352.694690
# South Korea     12184.867481
# UK              12161.474784
# Indonesia       12151.267472
# Mexico          12058.054255
# Turkey          11882.584874
# Spain           11796.579075
# Name: Total Water Consumption (Billion Cubic Meters), dtype: float64

# %%
df_2000 = df[df['Year'] == 2000]
df_2024 = df[df['Year'] == 2024]

df_crescita = df_2024[['Country','Total Water Consumption (Billion Cubic Meters)']].set_index('Country')-\
              df_2000[['Country','Total Water Consumption (Billion Cubic Meters)']].set_index('Country')

df_crescita.columns = ['Crescita assoluta']
df_top5 = df_crescita.sort_values(by = 'Crescita assoluta',ascending= False).head(5)

# %%
df_top5
# Out:
#              Crescita assoluta
# Country
# Germany             335.978727
# Argentina           166.300000
# South Korea         112.910625
# Australia            98.965000
# Canada               94.462260

# %%
df.set_index('Country')
# Out:
#            Year  Total Water Consumption (Billion Cubic Meters)  \
# Country
# Argentina  2000                                      481.490000
# Argentina  2001                                      455.063000
# Argentina  2002                                      482.749231
# Argentina  2003                                      452.660000
# Argentina  2004                                      634.566000
# ...         ...                                             ...
# USA        2020                                      418.097000
# USA        2021                                      572.094000
# USA        2022                                      440.978000
# USA        2023                                      566.865000
# USA        2024                                      249.485000
#
#            Per Capita Water Use (Liters per Day)  Agricultural Water Use (%)  \
# Country
# Argentina                             235.431429                   48.550000
# ...

# %%
df.loc.get('Italy')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df.loc.get('Italy')
#
# AttributeError: '_LocIndexer' object has no attribute 'get'

# %%
df.index.unique()
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df['Country'] == 'Italy'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Country, Length: 500, dtype: bool

# %%
Italy = df.loc[df['Country'] == 'Italy']
Italy
# Out:
#     Country  Year  Total Water Consumption (Billion Cubic Meters)  \
# 225   Italy  2000                                      365.118333
# 226   Italy  2001                                      668.278000
# 227   Italy  2002                                      613.631429
# 228   Italy  2003                                      446.749000
# 229   Italy  2004                                      604.734444
# 230   Italy  2005                                      482.913077
# 231   Italy  2006                                      383.605000
# 232   Italy  2007                                      646.318182
# 233   Italy  2008                                      476.843846
# 234   Italy  2009                                      417.709091
# 235   Italy  2010                                      631.625000
# 236   Italy  2011                                      482.022222
# 237   Italy  2012                                      574.142727
# ...

# %%
Italy_statistiche = Italy.groupby('Country').agg({'mean','median','std'})

# %%
Italy_statistiche
# Out:
#            Year                    \
#          median       std    mean
# Country
# Italy    2012.0  7.359801  2012.0
#
#         Total Water Consumption (Billion Cubic Meters)                        \
#                                                 median       std        mean
# Country
# Italy                                       482.022222  96.57175  497.985261
#
#         Per Capita Water Use (Liters per Day)                         \
#                                        median        std        mean
# Country
# Italy                              280.412727  55.994422  284.196263
#
#         Agricultural Water Use (%)  ... Industrial Water Use (%)  \
#                             median  ...                     mean
# Country                             ...
# Italy                        50.85  ...                28.078849
#
#         Household Water Use (%)                       \
#                          median       std       mean
# Country
# ...
